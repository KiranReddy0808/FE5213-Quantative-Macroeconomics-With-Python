# %% [markdown]
# # Introduction to Pandas for Excel Users
#
# Welcome to this introduction to Pandas, a powerful data analysis library in Python. If you're an Excel user who has never used Python before, this notebook is designed just for you!
#
# ### What is Pandas?
# Pandas is an open-source library in Python, widely used for data analysis and manipulation. It is somewhat similar to Microsoft Excel but has many more powerful features for working with data programmatically. You can perform operations like reading data, cleaning it, manipulating it, and visualizing it.
#
# Throughout this notebook, we'll illustrate how you can perform common data analysis tasks with Pandas and compare them with equivalent Excel operations.

# %%
# Import necessary libraries
import pandas as pd
import yfinance as yf

# %% [markdown]
# ## Fetching Stock Data from Yahoo Finance
#
# We will use the Yahoo Finance API to fetch some stock data for demonstration. This data includes information like stock prices, volume, and more. If you are familiar with importing data into Excel, this is similar to getting data from an external data source.
#
# The Yahoo Finance API can be accessed using the `yfinance` package. Let’s fetch some data for a popular stock: Apple Inc. (AAPL).

# %%
# Fetch stock data for Apple (AAPL)
aapl_data = yf.download('AAPL', period='max') # start='2022-01-01', end='2023-01-01')
print(type(aapl_data))
# Display the first few rows of data
# Out:
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.frame.DataFrame'>

# %%
aapl_data.head(10)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.098943  469033600
# 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.093781  175884800
# 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.086898  105728000
# 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089049   86441600
# 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.091631   73449600
# 1980-12-19  0.126116  0.126674  0.126116  0.126116   0.097223   48630400
# 1980-12-22  0.132254  0.132813  0.132254  0.132254   0.101954   37363200
# 1980-12-23  0.137835  0.138393  0.137835  0.137835   0.106257   46950400
# 1980-12-24  0.145089  0.145647  0.145089  0.145089   0.111849   48003200
# 1980-12-26  0.158482  0.159040  0.158482  0.158482   0.122173   55574400

# %% [markdown]
# ## Basic Operations with Pandas
#
# In Excel, you might use features like **Filters**, **Formulas**, and **Pivot Tables** to analyze your data. Pandas has similar functionalities but with much greater flexibility.
#
# ### 1. Viewing Data
# You can view the first few rows of a DataFrame using the `.head()` method.
#
# ```python
# aapl_data.head()
# ```
#
# You can also view the last few rows using the `.tail()` method.
#
# ```python
# aapl_data.tail()
# ```
#
# ### 2. Checking the Data Types
# In Excel, data types are usually inferred when you enter data into cells. In Pandas, you can check the types of columns using the `.dtypes` attribute.
#
# ```python
# aapl_data.dtypes
# ```
#
# This helps to understand the kind of data you're working with: numerical, categorical, date, etc.

# %%
# Viewing last few rows
print(aapl_data.tail())

# Checking data types
aapl_data.dtypes
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-09-25  224.929993  227.289993  224.020004  226.369995  226.369995
# 2024-09-26  227.300003  228.500000  225.410004  227.520004  227.520004
# 2024-09-27  228.460007  229.520004  227.300003  227.789993  227.789993
# 2024-09-30  230.039993  233.000000  229.649994  233.000000  233.000000
# 2024-10-01  229.520004  229.649994  223.740005  226.210007  226.210007
#
#               Volume
# Date
# 2024-09-25  42308700
# 2024-09-26  36636700
# 2024-09-27  34026000
# 2024-09-30  54541900
# 2024-10-01  62940000
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %% [markdown]
# ### 3. Filtering Data
# In Excel, you can filter data using dropdown menus. In Pandas, you can do the same programmatically.
#
# Let's filter the data to show only the days where the closing price was greater than $150.
#
# ```python
# filtered_data = aapl_data[aapl_data['Close'] > 150]
# filtered_data.head()
# ```

# %%
(1 * (aapl_data['Close'] > 150)).loc['2005-01-01':].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Filtering data where closing price is greater than $150
filtered_data = aapl_data[aapl_data['Close'] > 150]
filtered_data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-08-16  148.539993  151.190002  146.470001  151.119995  148.631104
# 2021-08-17  150.229996  151.679993  149.089996  150.190002  147.716415
# 2021-08-30  149.000000  153.490005  148.610001  153.119995  150.598160
# 2021-08-31  152.660004  152.800003  151.289993  151.830002  149.329407
# 2021-09-01  152.830002  154.979996  152.339996  152.509995  149.998215
#
#                Volume
# Date
# 2021-08-16  103296000
# 2021-08-17   92229700
# 2021-08-30   90956700
# 2021-08-31   86453100
# 2021-09-01   80313700

# %% [markdown]
# ### 4. Descriptive Statistics
# In Excel, you may use functions like `AVERAGE()`, `SUM()`, `MIN()`, `MAX()` to get summary statistics. In Pandas, you can easily get these statistics for all columns using the `.describe()` method.
#
# ```python
# aapl_data.describe()
# ```

# %%
# Get descriptive statistics
aapl_data.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  11042.000000  11042.000000  11042.000000  11042.000000  11042.000000
# mean      23.096208     23.344647     22.857607     23.111317     22.296140
# std       47.611970     48.120843     47.134013     47.650351     47.205794
# min        0.049665      0.049665      0.049107      0.049107      0.037856
# 25%        0.299107      0.305357      0.292076      0.299107      0.242593
# 50%        0.535714      0.542411      0.526786      0.535714      0.436048
# 75%       20.599465     20.761607     20.374286     20.574375     17.581141
# max      236.479996    237.229996    233.089996    234.820007    234.548523
#
#              Volume
# count  1.104200e+04
# mean   3.170367e+08
# std    3.352012e+08
# min    0.000000e+00
# 25%    1.123749e+08
# 50%    2.047920e+08
# 75%    3.977848e+08
# max    7.421641e+09

# %% [markdown]
# ## Data Visualization
# One of the strengths of using Pandas and Python is the ability to easily visualize your data. You can use the `.plot()` method to quickly generate plots.
#
# Let's plot the closing price of the stock over time:
#
# ```python
# aapl_data['Close'].plot(title='Apple Stock Closing Prices (2022)')
# ```

# %%
# Plotting the closing prices
aapl_data['Close'].plot(title=f'Apple Stock Closing Prices as of {aapl_data.index[-1]}', figsize=(10, 6))
# Out:
# <Axes: title={'center': 'Apple Stock Closing Prices as of 2024-10-01 00:00:00'}, xlabel='Date'>

# %%
# how does Pandas know how to interpret the dates?
# It uses a special data formal, pd.datetime
aapl_data.index[100]
# Out:
# Timestamp('1981-05-07 00:00:00')

# %%
pd.to_datetime('2022-01-01')
# Out:
# Timestamp('2022-01-01 00:00:00')

# %% [markdown]
# ## Saving Data to Excel
# After performing data manipulations, you might want to save your results back to an Excel file. Pandas makes it easy to do so using the `.to_excel()` method.
#
# ```python
# filtered_data.to_excel('filtered_aapl_data.xlsx', index=False)
# ```
#
# This will save the filtered data to an Excel file named `filtered_aapl_data.xlsx`.

# %%
# Save filtered data to Excel
filtered_data.to_excel('filtered_aapl_data.xlsx', index=False)

# %% [markdown]
# ## Conclusion
# This notebook provided a basic introduction to using Pandas for data analysis, especially aimed at Excel users. We covered:
#
# - Fetching data from Yahoo Finance
# - Viewing and inspecting data
# - Filtering and analyzing data
# - Visualizing data
# - Saving data back to Excel
#
# There is so much more you can do with Pandas, and we encourage you to explore further. Happy analyzing!
